# %%
import pandas as pd
import glob

arquivos = glob.glob('../data/2 - results/*_results.csv')
df = pd.concat([pd.read_csv(f) for f in arquivos], ignore_index=True)

# %%
df[~df['Error_Log'].isna()][['Preprocessor', 'Error_Log']].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [Preprocessor, Error_Log]
# Index: []
