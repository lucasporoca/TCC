# %% [markdown]
# - Correção dos pré-processadores de outliers
# - ROC AUC X MCC
# - Cenários

# %%
import pandas as pd
import glob

arquivos = glob.glob('../data/4 - results/*_results.csv')
df = pd.concat([pd.read_csv(f) for f in arquivos], ignore_index=True).drop(['Error_Log'], axis=1)
df
# Out:
#                        Dataset       Model     Preprocessor  Fold  \
# 0      banknote-authentication  GaussianNB         Baseline     1
# 1      banknote-authentication  GaussianNB         Baseline     2
# 2      banknote-authentication  GaussianNB         Baseline     3
# 3      banknote-authentication  GaussianNB         Baseline     4
# 4      banknote-authentication  GaussianNB         Baseline     5
# ...                        ...         ...              ...   ...
# 25195                     wilt         MLP  SMOTE / SMOTENC     6
# 25196                     wilt         MLP  SMOTE / SMOTENC     7
# 25197                     wilt         MLP  SMOTE / SMOTENC     8
# 25198                     wilt         MLP  SMOTE / SMOTENC     9
# 25199                     wilt         MLP  SMOTE / SMOTENC    10
#
#        Fit_Time_sec  Predict_Time_Test_sec  Peak_Memory_MB  \
# 0          0.000000               0.015625        0.150799
# ...
