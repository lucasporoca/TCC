# %% [markdown]
# - Correção dos pré-processadores de outliers
# - ROC AUC X MCC
# - Cenários

# %%
import pandas as pd
import glob

arquivos = glob.glob('../data/4 - results/2 - scaled/*_results.csv')
df = pd.concat([pd.read_csv(f) for f in arquivos], ignore_index=True)
df
# Out:
#                        Dataset       Model Preprocessor  Fold  Fit_Time_sec  \
# 0      banknote-authentication  GaussianNB     Baseline   1.0      0.000000
# 1      banknote-authentication  GaussianNB     Baseline   2.0      0.015625
# 2      banknote-authentication  GaussianNB     Baseline   3.0      0.015625
# 3      banknote-authentication  GaussianNB     Baseline   4.0      0.000000
# 4      banknote-authentication  GaussianNB     Baseline   5.0      0.000000
# ...                        ...         ...          ...   ...           ...
# 23095                     wilt     XGBoost  Yeo-Johnson   6.0      0.109375
# 23096                     wilt     XGBoost  Yeo-Johnson   7.0      0.109375
# 23097                     wilt     XGBoost  Yeo-Johnson   8.0      0.109375
# 23098                     wilt     XGBoost  Yeo-Johnson   9.0      0.109375
# 23099                     wilt     XGBoost  Yeo-Johnson  10.0      0.109375
#
# ...
